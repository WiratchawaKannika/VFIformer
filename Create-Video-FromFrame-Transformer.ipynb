# %%
# importing libraries
import os
import cv2
from PIL import Image
import pandas as pd
import shutil as sh

# %% [markdown]
# # Copy() image to all Directory

# %%
import glob

## inter Images
data_test = '/media/SSD/rheology_data/'
# relative path to search all .png files
files = glob.glob(f"{data_test}test_our_demo/*.png")
print(len(files))
files.sort()
#files
for file in files:
    f_name  = file.split('/')[-1]
    print(f_name)
    if not os.path.exists('{}rheology_data_inter'.format(data_test)) :
            os.makedirs('{}rheology_data_inter'.format(data_test))
    sh.copy("{}test_our_demo/{}".format(data_test,f_name),"{}rheology_data_inter".format(data_test))
# Out:
# 610
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000008_inter.png
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000018_inter.png
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000020_inter.png
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000022_inter.png
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000024_inter.png
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000026_inter.png
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000030_inter.png
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000032_inter.png
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000034_inter.png
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000036_inter.png
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000040_inter.png
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000042_inter.png
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000044_inter.png
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000046_inter.png
# ...

# %%
import glob

#Origianl images
data_test = '/media/SSD/rheology_data/'
# relative path to search all .png files
files = glob.glob(f"{data_test}GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/*.jpg")
print(len(files))
files.sort()
#files
for file in files:
    f_name  = file.split('/')[-1]
    print(f_name)
    sh.copy("{}GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/{}".format(data_test,f_name),"{}rheology_data_inter".format(data_test))
# Out:
# 1220
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000008.jpg
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000009.jpg
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000018.jpg
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000019.jpg
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000020.jpg
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000021.jpg
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000022.jpg
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000023.jpg
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000024.jpg
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000025.jpg
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000026.jpg
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000027.jpg
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000030.jpg
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000031.jpg
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000032.jpg
# ...

# %%
# folder_root = '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/'
# num_of_images = len(os.listdir(folder_root))
# num_of_images
# for file in os.listdir(folder_root):
#     print(file)

# %%
# for file in os.listdir(folder_root):
#     if file.endswith(".jpg") or file.endswith(".jpeg") or file.endswith("png"):
#         # opening image using PIL Image
#         im = Image.open(os.path.join(folder_root, file))
#         # im.size includes the height and width of image
#         width, height = im.size
#         print(width, height)

# %%
# folder_root = '/media/SSD/rheology_data/test_our_demo/'
# for file in os.listdir(folder_root):
#     if file.endswith(".jpg") or file.endswith(".jpeg") or file.endswith("png"):
#         # opening image using PIL Image
#         im = Image.open(os.path.join(folder_root, file))
#         # im.size includes the height and width of image
#         width, height = im.size
#         print(width, height)

# %%
def Resizing_img(folder_root, save_folder):
    # Folder which contains all the images
    # from which video is to be generated
    if not os.path.exists(save_folder):
        os.makedirs(save_folder)
    os.chdir(save_folder)
    
    mean_height = 0
    mean_width = 0
    num_of_images = len(os.listdir(folder_root))
    # print(num_of_images)

    for file in os.listdir(folder_root):
        im = Image.open(os.path.join(folder_root, file))
        width, height = im.size
        mean_width += width
        mean_height += height
        # im.show() # uncomment this for displaying the image

    # Finding the mean height and width of all images.
    # This is required because the video frame needs
    # to be set with same width and height. Otherwise
    # images not equal to that width height will not get
    # embedded into the video
    mean_width = int(mean_width / num_of_images)
    mean_height = int(mean_height / num_of_images)

    # print(mean_height)
    # print(mean_width)

    # Resizing of the images to give
    # them same width and height
    for file in os.listdir(folder_root):
        if file.endswith(".jpg") or file.endswith(".jpeg") or file.endswith("png"):
            # opening image using PIL Image
            im = Image.open(os.path.join(folder_root, file))
            # im.size includes the height and width of image
            width, height = im.size
            print(width, height)
            # resizing
            imResize = im.resize((mean_width, mean_height), Image.ANTIALIAS)
            imResize.save(file, 'JPEG', quality = 95) # setting quality
            # printing each resized image name
            print(file, " is resized")

# %% [markdown]
# ## Resize Original images

# %%
folder_root = '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/'
save_folder = '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_resize/'
Resizing_img(folder_root, save_folder)
# Out:
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000001978.jpg  is resized
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000001213.jpg  is resized
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000551.jpg  is resized
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000001626.jpg  is resized
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000686.jpg  is resized
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000584.jpg  is resized
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000440.jpg  is resized
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000556.jpg  is resized
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000971.jpg  is resized
# 800 800
# /tmp/ipykernel_66749/3760647503.py:41: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
# ...

# %% [markdown]
# ## Resize Inter_ images

# %%
folder_root = '/media/SSD/rheology_data/test_our_demo/'
save_folder = '/media/SSD/rheology_data/test_our_demo_resize/'
Resizing_img(folder_root, save_folder)
# Out:
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000468_inter.png  is resized
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000001705_inter.png  is resized
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000609_inter.png  is resized
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000001177_inter.png  is resized
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000001950_inter.png  is resized
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000001599_inter.png  is resized
# 800 800
# /tmp/ipykernel_66749/3760647503.py:41: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   imResize = im.resize((mean_width, mean_height), Image.ANTIALIAS)
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000740_inter.png  is resized
# 800 800
# GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000001670_inter.png  is resized
# 800 800
# ...

# %% [markdown]
# -----------------

# %%
# image_folder = save_folder
# images = [img for img in os.listdir(image_folder) if img.endswith(".jpg") or
#          img.endswith(".jpeg") or img.endswith("png")]

# %%
#images

# %%
# frame = cv2.imread(os.path.join(image_folder, images[0]))
# frame

# %%
# path_txt = '/media/SSD/rheology_data/test.txt'
# with open(path_txt, 'r') as txt:
#          sequence_list = [line.strip() for line in txt]
#     #for images in sequence_list:
# images = [img for img in sequence_list
#         if img.endswith(".jpg") or
#             img.endswith(".jpeg") or
#             img.endswith("png")]
# images

# %%
# frame = cv2.imread(images[0])
# frame

# %%
# Video Generating function
def generate_video(video_name, path_txt, Cdir):
#	image_folder = '.' # make sure to use your folder
	video_name = f'{video_name}.avi'
#	video_name = f'{video_name}.mp4'
	os.chdir(Cdir)
	with open(path_txt, 'r') as txt:
         sequence_list = [line.strip() for line in txt]
    #for images in sequence_list:
	images = [img for img in sequence_list
			if img.endswith(".jpg") or
				img.endswith(".jpeg") or
				img.endswith("png")]
	
	# Array images should only consider
	# the image files ignoring others if any
	print(images)

	frame = cv2.imread(images[0])

	# setting the frame width, height width
	# the width, height of first image
	height, width, layers = frame.shape

	video = cv2.VideoWriter(video_name, 0, 1, (width, height))

	# Appending the images to the video one by one
	for image in images:
		video.write(cv2.imread(image))
	
	# Deallocating memories taken for window creation
	cv2.destroyAllWindows()
	video.release() # releasing the video generated

# %% [markdown]
# # Prepare images path to creat VDO

# %%
import glob

data_root = '/media/SSD/rheology_data/'
pth_img = data_root + 'rheology_data_inter/'

sequence_frame = list()
with open(os.path.join(data_root, 'test-demo.txt'), 'r') as txt:
     sequence_list = [line.strip() for line in txt]
for seq in sequence_list:
    img0_path, img1_path = seq.split(' ')
    img0_path_ = os.path.join(pth_img, os.path.basename(img0_path))
    img1_path_ = os.path.join(pth_img, os.path.basename(img1_path))
    img_inter = os.path.join(pth_img, os.path.basename(img0_path).split('.')[0]+'_inter'+'.png')
    sequence_frame.append([img0_path_, img_inter, img1_path_])
## make a flat list out of a list of lists
flat_sequence = []
for sublist in sequence_frame:
    for item in sublist:
        flat_sequence.append(item)

# %%
print(len(flat_sequence))
flat_sequence
# Out:
# 1830
# ['/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000008.jpg',
#  '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000008_inter.png',
#  '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000009.jpg',
#  '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000018.jpg',
#  '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000018_inter.png',
#  '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000019.jpg',
#  '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000020.jpg',
#  '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000020_inter.png',
# ...

# %%
## Save Text 
with open(f'{data_root}rheology_data_inter.txt', 'w') as f:
    for line in flat_sequence:
        f.write("%s\n" % line)

# %%
# import glob

# pth = '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_resize/'
# save_pth = '/media/SSD/rheology_data/'
# # relative path to search all text files
# files = glob.glob(f"{pth}*.jpg")
# print(len(files))
# #print(files)
# with open(f'{save_pth}test-resize.txt', 'w') as f:
#     for line in files:
#         f.write("%s\n" % line)

# %%
# with open(f'{save_pth}test-resize.txt') as f:
#     print(f.read())

# %%
# a = open(f'{save_pth}test-resize.txt', 'r').readlines()

# final = []
# buf = []
# for line in a:
#    if len(line.strip()) != 0:
#        buf.append(line.strip())
#    if len(buf) == 2:
#        final.append(' '.join(a for a in buf) + '\n')
#        buf.clear()

# outF = open(f"{save_pth}test-demo-resize.txt", "w")
# outF.writelines(final)
# outF.close()

# %%
# with open(f'{save_pth}test-demo-resize.txt') as f:
#     print(f.read())

# %%
# img0_path
# os.path.join(pth, os.path.basename(img0_path))

# %% [markdown]
# ## Generate video from Original images

# %%
# with open(f'{data_root}test-resize.txt') as f:
#     print(f.read())
with open(os.path.join(data_root, 'test.txt'), 'r') as txt:
     sequence_list = [line.strip() for line in txt]
print(len(sequence_list))
sequence_list
# Out:
# 1220
# ['/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000008.jpg',
#  '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000009.jpg',
#  '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000018.jpg',
#  '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000019.jpg',
#  '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000020.jpg',
#  '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000021.jpg',
#  '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000022.jpg',
# ...

# %%
# Calling the generate_video function
video_name = 'rheology-frame'
path_txt = data_root + 'test.txt'
Cdir = data_root
generate_video(video_name, path_txt, Cdir)
# Out:
# ['/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000008.jpg', '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000009.jpg', '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000018.jpg', '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000019.jpg', '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000020.jpg', '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000021.jpg', '/media/SSD/rheology_data/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000022.jpg', '/media/SSD/rheology_data/GLY40P100_D0
# ...

# %%
# import cv2
# cap = cv2.VideoCapture(f"{data_root}{video_name}")  
# fps = cap.get(cv2.CAP_PROP_FPS)   #frames per second
# frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))   #total number of frames
# duration = frame_count/fps
# duration

# %%
## VDO 1220 วินาที มี 1220 frame 
60*20+20
# Out:
# 1220

# %%
1220/60
# Out:
# 20.333333333333332

# %%
1220/60
# Out:
# 20.333333333333332

# %%
# Calling the generate_video function
video_name = 'rheology-frame_inter'
path_txt = data_root + 'rheology_data_inter.txt'
Cdir = data_root
generate_video(video_name, path_txt, Cdir)
# Out:
# ['/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000008.jpg', '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000008_inter.png', '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000009.jpg', '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000018.jpg', '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000018_inter.png', '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000019.jpg', '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000020.jpg', '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000020_inter.png', '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_000000
# ...

# %%
# with open(f'{data_root}test-resize.txt') as f:
#     print(f.read())
with open(os.path.join(data_root, 'rheology_data_inter.txt'), 'r') as txt:
     sequence_list = [line.strip() for line in txt]
print(len(sequence_list))
# Out:
# 1830

# %%
60*30+30
# Out:
# 1830

# %%
1830/60
# Out:
# 30.5

# %%
# with open(f'{data_root}test-resize.txt') as f:
#     print(f.read())
with open(os.path.join(data_root, 'rheology_data_inter.txt'), 'r') as txt:
     sequence_list = [line.strip() for line in txt]
#print(len(sequence_list))
# for seq in sequence_list:
#     image = cv2.imread(seq)
#     plt.axis("off")
#     plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#     plt.show()

# %%
sequence_list[:3]
# Out:
# ['/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000008.jpg',
#  '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000008_inter.png',
#  '/media/SSD/rheology_data/rheology_data_inter/GLY40P100_D0_30HZ_20XINF_UWELL_20220721_135136_0000000009.jpg']

# %%
1220/60
# Out:
# 20.333333333333332
