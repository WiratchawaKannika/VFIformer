# %%
import json 
import pandas as pd
import numpy as np
from pathlib import Path
import PIL
from PIL import Image
import cv2 
import torch
import os

# %% [markdown]
# # 📂 IMport Random Directory

# %%
ranfold= pd.read_csv('/home/kannika/codes_AI/CSV/rheology2023_random40folder.csv')
print(ranfold.shape)
ranfold.head()
# Out:
# (40, 2)
#    Unnamed: 0                                         FolderPath
# 0           0  /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XIN...
# 1           1  /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XIN...
# 2           2  /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XIN...
# 3           3  /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XIN...
# 4           4  /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XIN...

# %%
FolderPath = ranfold['FolderPath'].tolist()
print(len(FolderPath))
FolderPath
# Out:
# 40
# ['/media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_174116',
#  '/media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_182704',
#  '/media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221223_122706',
#  '/media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_214317',
#  '/media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_215050',
#  '/media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_121950',
#  '/media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055220',
#  '/media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_123202',
#  '/media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_120633',
#  '/media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055529',
#  '/media/SSD/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204',
#  '/media/SSD/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_074912',
#  '/media/SSD/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_204812',
#  '/media/SSD/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_071956',
#  '/media/SSD/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_193350',
#  '/media/SSD/rheology2023/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221229_155527',
#  '/media/SSD/rheology2023/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_161452',
#  '/media/SSD/rheology2023/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_145100',
#  '/media/SSD/rheology2023/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221229_164322',
#  '/media/SSD/rheology2023/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_151430',
#  '/media/SSD/rheology2023/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_063932',
#  '/media/SSD/rheology2023/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_090816',
#  '/media/SSD/rheology2023/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_064454',
#  '/media/SSD/rheology2023/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_082049',
#  '/media/SSD/rheology2023/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_065231',
#  '/media/SSD/rheology2023/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_100941',
#  '/media/SSD/rheology2023/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_160237',
#  '/media/SSD/rheology2023/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_093937',
#  '/media/SSD/rheology2023/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_155531',
#  '/media/SSD/rheology2023/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_091417',
#  '/media/SSD/rheology2023/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_203150',
#  '/media/SSD/rheology2023/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_195610',
#  '/media/SSD/rheology2023/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221230_091704',
#  '/media/SSD/rheology2023/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_195148',
#  '/media/SSD/rheology2023/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_193632',
#  '/media/SSD/rheology2023/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115038',
#  '/media/SSD/rheology2023/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_122311',
#  '/media/SSD/rheology2023/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115310',
#  '/media/SSD/rheology2023/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_121932',
#  '/media/SSD/rheology2023/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115540']

# %% [markdown]
# # 🌺Create sequence folder

# %%
## ** Set Modrl Inter Frame
Model_inter = "VFIformer"

# %%
## /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer ## path**-- path to create
## original path ** /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_174116
lst_Folder2cre = []
for i in range(len(FolderPath)):
    FolderPath0 = FolderPath[i]
    Folder2cre = FolderPath0.replace("rheology2023", f"Frame_Inter_rheology2023/Frame_Inter/{Model_inter}")
    Folder2cre_ = Folder2cre+'-sequence'
    lst_Folder2cre.append(Folder2cre_)
    print(f'On process Create Folder -->> [ {Folder2cre_} ]')
    os.makedirs(Folder2cre_, exist_ok=True)
# Out:
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_174116-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_182704-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221223_122706-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_214317-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_215050-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_121950-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055220-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_123202-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_120633-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055529-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_074912-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_204812-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_071956-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_193350-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221229_155527-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_161452-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_145100-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221229_164322-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_151430-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_063932-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_090816-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_064454-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_082049-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_065231-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_100941-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_160237-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_093937-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_155531-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_091417-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_203150-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_195610-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221230_091704-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_195148-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_193632-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115038-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_122311-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115310-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_121932-sequence ]
# On process Create Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115540-sequence ]

# %%
print(len(lst_Folder2cre))
lst_Folder2cre
# Out:
# 40
# ['/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_174116-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_182704-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221223_122706-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_214317-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_215050-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_121950-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055220-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_123202-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_120633-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055529-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_074912-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_204812-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_071956-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_193350-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221229_155527-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_161452-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_145100-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221229_164322-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_151430-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_063932-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_090816-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_064454-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_082049-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_065231-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_100941-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_160237-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_093937-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_155531-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_091417-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_203150-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_195610-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221230_091704-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_195148-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_193632-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115038-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_122311-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115310-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_121932-sequence',
#  '/media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115540-sequence']

# %% [markdown]
# ## 🌺 Copy() image to all Directory

# %%
## Copy images from original path 
## เปลี่ยนแค่  VFIformer -->> เป็นชื่อ Folder ของ Model อื่น
import glob
import shutil as sh

for i in range(len(FolderPath)):
    FolderPath0 = FolderPath[i]
    img_ori = glob.glob(f"{FolderPath0}/*.jpg")
    img_ori.sort()
    print(f'On process Copy Images from Original Folder -->> [ {FolderPath0} ]')
    folderNew = FolderPath0.replace("rheology2023", f"Frame_Inter_rheology2023/Frame_Inter/{Model_inter}")
    inter = folderNew+'-inter'  ##--Folder2save
    img_inter = glob.glob(f"{inter}/*.png")
    img_inter.sort()
    print(f'On process Copy Images from inter frame Folder -->> [ {inter} ]')
    Folder2cre = folderNew+'-sequence'  ##--Folder2save
    for img0 in img_ori:
        imgName0 = img0.split('/')[-1]
        sh.copy(img0, "{}/{}".format(Folder2cre ,imgName0))
    for img1 in img_inter:
        imgName1 = img1.split('/')[-1]
        sh.copy(img1, "{}/{}".format(Folder2cre ,imgName1))
    print(f'( {i+1}.)  process Copy Images To Sequence Folder -->> [ {Folder2cre} ]')
    print('-'*120)
# Out:
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_174116 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_174116-inter ]
# ( 1.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_174116-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_182704 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_182704-inter ]
# ( 2.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_182704-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221223_122706 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221223_122706-inter ]
# ( 3.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221223_122706-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_214317 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_214317-inter ]
# ( 4.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_214317-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_215050 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_215050-inter ]
# ( 5.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_215050-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_121950 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_121950-inter ]
# ( 6.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_121950-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055220 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055220-inter ]
# ( 7.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055220-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_123202 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_123202-inter ]
# ( 8.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_123202-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_120633 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_120633-inter ]
# ( 9.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_120633-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055529 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055529-inter ]
# ( 10.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055529-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204-inter ]
# ( 11.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_074912 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_074912-inter ]
# ( 12.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_074912-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_204812 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_204812-inter ]
# ( 13.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_204812-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_071956 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_071956-inter ]
# ( 14.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_071956-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_193350 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_193350-inter ]
# ( 15.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_193350-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221229_155527 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221229_155527-inter ]
# ( 16.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221229_155527-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_161452 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_161452-inter ]
# ( 17.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_161452-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_145100 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_145100-inter ]
# ( 18.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_145100-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221229_164322 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221229_164322-inter ]
# ( 19.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221229_164322-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_151430 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_151430-inter ]
# ( 20.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY30/GLY30P100_D0_30HZ_20XINF_UWELL_20221228_151430-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_063932 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_063932-inter ]
# ( 21.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_063932-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_090816 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_090816-inter ]
# ( 22.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_090816-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_064454 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_064454-inter ]
# ( 23.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_064454-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_082049 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_082049-inter ]
# ( 24.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_082049-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_065231 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_065231-inter ]
# ( 25.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY60/GLY60P100_D0_30HZ_20XINF_UWELL_20221228_065231-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_100941 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_100941-inter ]
# ( 26.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_100941-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_160237 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_160237-inter ]
# ( 27.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_160237-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_093937 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_093937-inter ]
# ( 28.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_093937-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_155531 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_155531-inter ]
# ( 29.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_155531-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_091417 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_091417-inter ]
# ( 30.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY20/GLY20P100_D0_30HZ_20XINF_UWELL_20221227_091417-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_203150 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_203150-inter ]
# ( 31.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_203150-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_195610 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_195610-inter ]
# ( 32.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_195610-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221230_091704 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221230_091704-inter ]
# ( 33.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221230_091704-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_195148 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_195148-inter ]
# ( 34.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_195148-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_193632 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_193632-inter ]
# ( 35.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY40/GLY40P100_D0_30HZ_20XINF_UWELL_20221227_193632-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115038 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115038-inter ]
# ( 36.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115038-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_122311 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_122311-inter ]
# ( 37.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_122311-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115310 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115310-inter ]
# ( 38.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115310-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_121932 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_121932-inter ]
# ( 39.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_121932-sequence ]
# ------------------------------------------------------------------------------------------------------------------------
# On process Copy Images from Original Folder -->> [ /media/SSD/rheology2023/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115540 ]
# On process Copy Images from inter frame Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115540-inter ]
# ( 40.)  process Copy Images To Sequence Folder -->> [ /media/SSD/Frame_Inter_rheology2023/Frame_Inter/VFIformer/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_115540-sequence ]
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -----------------------------
